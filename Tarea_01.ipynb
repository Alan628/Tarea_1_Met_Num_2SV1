# %% [markdown]
# 1.- Desarrollar un programa que lea una variable de tipo entera value, indique si es un numero
# par o impar.

# %%
num= int(input("Digite el numero a evaluar: "))
if num%2==0:
  print("El numero es entero: ", num);
else:
  print("El numero es impar: ", num);  
print("Fin del programa");

# %% [markdown]
# 2.- Desarrolle un programa en el que el usuario introduzca una cadena de caracteres y un numero
# entero, despues el programa debe de imprimir la cadena de caracteres tantas veces como el
# nuemero entero

# %%
print("Digite la palabra deseada: ") 
Texto=input() 
print("Digite cuantas veces quiere que se repita el texto: ") 
Veces=int(input()) 
cont=0 
while cont<Veces: 
  cont+=1 
  print(Texto) 

print("Fin del programa")

# %% [markdown]
# 3.- Escribir una funcion que reciba como argumentos el numero de horas y el costo por hora dejarlo
# como argumento predefinido en 150 la funcion debe de regresar el pago del empleado en un
# dıa, en una semana (5 dıas) y en un mes (20 dıas).

# %%
Hora= float(input("Digite el numero de horas: "))
Salario= float(150) 
Dia= print("Un dia de trabajo: ", Hora*Salario) 
Semana= print("Una semana de trabajo: ", Hora*Salario*5) 
Mes= print("Un mes de trabajo: ", Hora*Salario*20)

print("Fin del programa")

# %% [markdown]
# 4.-Escribir el codigo de una calculadora, que inicialmente muestre el menu y dependiendo de la
# opcion elegida por el usuario se desarrolle la operacion, observe que en la division el denominador no puede ser cero, en caso que sea ası, debe de entrar en un bucle while que este leyendo
# el denominador de nuevo hasta que este sea distinto de cero

# %%
print("                   CALCULADORA") 
print("El siguiente programa resuelve 4 tipos de operaciones como son:")
print("Menu de opciones") 
print("1)Suma,  2)Resta,  3)Multiplicacion, 4)Dvision")
resultado=""
while resultado!="no": 
  Menu=['1) Suma','2) Resta','3) Multiplicacion','4) Dvision']
  print("Elija una opcion del menu")
  Menu=int(input())
  while Menu>=5: 
    print("Elija una opcion del menu")
    Menu= int(input()) 

  if Menu==1: 
    a= float(input("Introduzca el primer valor: "))
    b= float(input("Introduzca el segundo valor: "))
    print("La suma de", a, "y de", b, "es: ", a+b) 

  elif Menu==2: 
    c= float(input("Introduzca el primer valor: "))
    d= float(input("Introduzca el segundo valor: "))
    print("La resta de", c, "y de", d, "es: ", c-d) 

  elif Menu==3: 
    e= float(input("Introduzca el primer valor: "))
    f= float(input("Introduzca el segundo valor: "))
    print("La multiplicaion de", e, "y de", f, "es: ", e*f) 

  elif Menu==4: 
    g= float(input("Introduzca el primer valor: "))
    h= float(input("Introduzca el segundo valor: "))
    while h==0:
      print("Digite un numero diferente de 0")
      h=float(input())
    print("La division de", g, "y de", h, "es: ", g/h)

  print("¿Quieres realizar otra operacion?")
  resultado=input()

print("Fin del programa")

# %% [markdown]
# 5.-Una tienda de juguetes tiene dos productos estrella, un payaso y un juego de mesa, el payaso
# pesa 150 gr y el juego de mesa pesa 170 gr. Hacer una funcion que reciba el numero de payasos
# y el numero de juegos de mesa por pedido, si el peso total del pedido es mayor a 10 kg, debe de mandar error, debe de inidicar por cuantos gramos se paso el envıo y debe de regresar False
# al programa principal.

# %%
print("Peso del pedido")
payaso=150
mesa=170
Total=100000
while Total>10000: 
  print("Digite el numero de payasos de su pedido: ")
  p=int(input())
  print("Digite el numero de juegos de mesa de su pedido:")
  m=int(input())
  Total=(((payaso*p)+(mesa*m)))
  print("El peso total del pedido es:" ,Total)
  if Total>=10000:
    print(Total<10000)
    Residuo=print("el pedido se excede por:",Total-10000) 

print("Fin del programa")dense }

# %% [markdown]
# 6.-Desarrolle una funcion que acepte como argumento el salario, y la funcion debe de mostrar el
# rango en que se encuentra, y debe de regresar el salario con el descuento del impuesto, si la
# funcion se ha podido desarrollar con exito, debe de regresar True

# %%
salario = int(input("Ingrese su salario: ")) 
if salario<=10000:
  print("El impuesto correspondiente es del 5%")
  impuesto=(salario*0.05)
  final=(salario-impuesto)
  print("El sueldo total con descuento de impuesto es: ", final) 
  print(salario <= 10000) 

elif salario<=15000:
  print("El impuesto correspondiente es del 10%")
  impuesto=(salario*0.10)
  final=(salario-impuesto)
  print("El sueldo total con descuento de impuesto es: ", final) 
  print(salario <= 15000) 

elif salario<=20000:
  print("El impuesto correspondiente es del 15%")
  impuesto=(salario*0.15)
  final=(salario-impuesto)
  print("El sueldo total con descuento de impuesto es: ", final) 
  print(salario <= 20000) 

elif salario>20000:
  print("El impuesto correspondiente es del 18%")
  impuesto=(salario*0.18)
  final=(salario-impuesto)
  print("El sueldo total con descuento de impuesto es: ", final) 
  print(salario > 20000) 

print("Fin del programa")

# %% [markdown]
# 7.-Escribir un programa para un museo, donde se deben de mandar a una funcion los siguientes
# parametros, edad y ocupacion. Se deben de aplicar los siguintes costos y descuentos

# %%
print("Sea bienvenido al museo, para entrar necesitamos saber su edad y ocupacion")
edad= int(input("Digite su edad: "))
if edad<4: 
  print("Su entrada es gratis, que de la disfrute")
  a=0
elif edad<16:
  print("El costo de su entrada es de $50")
  a=50
elif edad>16:
  print("El costo de su entrada es de $100")
  a=100
if a!=0:
  print("Digite su ocupacion")
  print("1) Estudiante con credencial")
  print("2) Docente con credencial")
  print("3) INAPAM")
  print("4) Otro")
  ocupacion= int(input("Digite el numero de su ocupacion: "))
  b=0 
  if ocupacion==1:
    print("Se le aplicara un descuento del 10%")
    b= (a*0.10)
  elif ocupacion==2: 
    print("Se le aplicara un descuento del 30%")
    b= (a*0.30)
  elif ocupacion==3:
    print("Se le aplicara un descuento del 50%")
    b= (a*0.50)
  else: 
    print("No se aplicara ningun descuento")
  c= (a-b)
  print("El monto total a pagar es de: ", c)

print("Fin del programa")

# %% [markdown]
# 8.-Escribir un programa que pida al usuario un numero entero y muestre en pantalla un trıangulo
# rectangulo el que se muestra.

# %%
triangulo= int(input("De que tamaño desea su triangulo: "))
for i in range(triangulo+1):
  print("*"*i)

print("Fin del programa")

# %% [markdown]
# 9.-Escribir una funcion que reciba un numero entero positivo y devuelva su factorial

# %%
a= int(input("Digite un numero para calcular su factorial: "))
b=1 
for i in range(a): 
  b= (b*a)
  a= (a-1)
print("El factorial del numero digiado es: ", b) 

print("Fin del programa")

# %% [markdown]
# 10.-Escribir una funcion que calcule el area de un cırculo y ota que calcule el volumen de un cilindro
# utilizando la primera funcion.

# %%
r= float(input("Introduzca el valor del radio: ")) 
h= float(input("Introduzca el valor de la altura: "))
pi= 3.1415922654  

area= (pi*r**2)
print("El valor del area es. ", area)

volumen= (area*h)
print("El valor del volumen es: ", volumen) 

print("Fin del programa")
